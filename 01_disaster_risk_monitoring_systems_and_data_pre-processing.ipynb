# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>

# %% [markdown]
# # Disaster Risk Monitoring Using Satellite Imagery #

# %% [markdown]
# ## 01 - Disaster Risk Monitoring Systems and Data Pre-processing ##
# In this notebook, you will learn the motivation behind this disaster risk monitoring and how to use hardware accelerated tools to process large image data.
#
# **Table of Contents**
# <br>
# This notebook covers the below sections:
# 1. [Disaster Risk Monitoring](#s1-1)
#     * [Flood Detection](#s1-1.1)
#     * [Satellite Imagery](#s1-1.2)
#     * [Computer Vision](#s1-1.3)
#     * [Deep Learning-Based Disaster Risk Monitoring Systems](#s1-1.4)
# 2. [Deep Learning Model Training Workflow](#s1-2)
#     * [Deep Learning Challenges](#s1-2.1)
# 3. [Introducing the Data Set](#s1-3)
#     * [Sentinel-1 Data Public Access](#s1-3.1)
#     * [Exploratory Data Analysis](#s1-3.2)
#     * [Exercise #1 - Count Input Data](#s1-e1)
#     * [Exercise #2 - Explore Tiles](#s1-e2)
# 4. [Data Pre-processing With DALI](#s1-4)
#     * [DALI Pipeline](#s1-4.1)
#     * [Data Augmentation](#s1-4.2)
#     * [Exercise #3 - Data Augmentation on Batch](#s1-e3)
#     * [Random Rotation](#s1-4.3)

# %% [markdown]
# <a name='s1-1'></a>
# ## Disaster Risk Monitoring ##
# Natural disasters such as flood, wildfire, drought, and severe storms wreak havoc throughout the world, causing billions of dollars in damages, and uprooting communities, ecosystems, and economies. The ability to detect, quantify, and potentially forecast natural disasters can help us minimize their adverse impacts on the economy and human lives. While this lab focuses primarily on detecting flood events, it should be noted that similar applications can be created for other natural disasters.

# %% [markdown]
# <a name='s1-1.1'></a>
# ### Flood Detection ###
# A [Flood](https://en.wikipedia.org/wiki/Flood) is an overflow of water that submerges land that is usually dry. They can occur under several conditions:
# * Overflow of water from water bodies, in which the water overtops or breaks levees (natural or man-made), resulting in some of that water escaping its usual boundaries
# * Accumulation of rainwater on saturated ground in an areal flood
# * When flow rate exceeds the capacity of the river channel
#
# Unfortunately, flooding events are on the rise due to climate change and sea level rise. Due to the increase in frequency and intensity, the topic of flood has garnered international attention in the past few years. In fact, organizations such as the United Nations has maintained effective response and proactive risk assessment for flood in their [Sustainable Development Goals](https://en.wikipedia.org/wiki/Sustainable_Development_Goals). The research of flood events and their evolution is an interdisciplinary study that requires data from a variety of sources such as:
# * Live Earth observation data via satellites and surface reflectance
# * Precipitation, runoff, soil moisture, snow cover, and snow water equivalent
# * Topography and meteorology
#
# The ability to detect flood and measure the extent of the disaster, can help decision makers develop tactical responses and scientists study flood behavior over time. Ultimately, we want to enable long-term mitigation strategies that are informed by science to help us achieve sustainability.

# %% [markdown]
# <a name='s1-1.2'></a>
# ### Satellite Imagery ###
# In this lab, we demonstrate the ability to create a flood detection segmentation model using satellite imagery. Using satellites to study flood is advantageous since physical access to flooded areas is limited and deploying instruments in potential flood zones can be dangerous. Furthermore, satellite remote sensing is much more efficient than manual or human-in-the-loop solutions.
#
# There are thousands of man-made satellites currently active in space. Once launched, a satellite is often placed in one of several orbits around Earth, depending on what the satellite is designed to achieve. Some satellites, such as those discussed in this lab, are used for Earth observation to help scientists learn about our planet while others could be used for communication or navigation purposes.
# <p><img src='images/orbits.png' width=720></p>
#
# Earth observation satellites have different capabilities that are suited for their unique purposes. To obtain detailed and valuable information for flood monitoring, satellite missions such as [Copernicus Sentinel-1](https://sentinel.esa.int/web/sentinel/missions/sentinel-1), provides C-band [**Synthetic Aperture Radar**](https://en.wikipedia.org/wiki/Synthetic-aperture_radar) (SAR) data. Satellites that use SAR, as oppose to _optical_ satellites that use visible or near-infrared bands, can operate day and night as well as under cloud cover. This form of radar is used to create two-dimensional images or three-dimensional reconstructions of objects, such as landscape. The two polar-orbiting Sentinel-1 satellites (Sentinel-1A and Sentinel-1B) maintain a repeat cycle of just _6_ days in the Lower Earth Orbit (LEO). Satellites that orbit close to Earth in the LEO enjoy the benefits of faster orbit speed and data transfer. These features make the Sentinel-1 mission very useful for monitoring flood risk over time. Thus, an real-time AI-based remote flood level estimation via Sentinel-1 data can prove game-changing.
# <p><img src='images/sentinel-1.jpg' width=720></p>
#
# More information about the Sentinel-1 mission can be found [here](https://directory.eoportal.org/web/eoportal/satellite-missions/c-missions/copernicus-sentinel-1).

# %% [markdown]
# <a name='s1-1.3'></a>
# ### Computer Vision ###
# At the heart of this type of disaster risk monitoring system is one or more machine learning models to generate insights from input data. These are generally deep learning neural network models that have been trained for a specific task. There are numerous approaches for drawing insight from images using machine learning such as:
# * **Classification** is used for identifying the object contained in an image. It is the task of labeling the given frame with one of the classes that the model has been trained with
# * **Object detection**, which includes image localization, can specify the location of multiple objects in a frame
#     * **Localization** uses regression to return the coordinates of the potential object within the frame
# * **Segmentation** provides pixel level accuracy by creating a fine-grained segmentation mask around the detected object. Applications for segmentation include: an AI powered green screen to blur or change the background of the frame, autonomous driving where you want to segment the road and background, or for manufacturing to identify microscopic level defects.
#     * **Semantic segmentation** associates every pixel of an image with a class label such as flood and not-flood. It treats multiple objects of the same class as a single entity.
#     * In contrast, **instance segmentation** treats multiple objects of the same class as distinct individual instances.
#
# <p><img src='images/computer_vision_tasks.jpg' width=720></p>
#
# For the purposes of detecting flood events, we will develop a _semantic segmentation_ model trained with labelled images that are generated from Sentinel-1 data.

# %% [markdown]
# <a name='s1-1.4'></a>
# ### Deep Learning-Based Disaster Risk Monitoring System ###
# The system that we envision consists of the below workflow:
# 1. Satellite remote sensing to captures data
# 2. Data is used to (continuously) train deep learning neural network models
# 3. Different models and versions are managed by the model repository
# 4. Model inference performance is actively monitored
# 5. Data is also passed to the inference server to generate insight
# 6. The deep learning-based insight can be used further analysis and/or raise alerts
# <p><img src='images/system_1.png' width=720></p>
#
# When processing data in real-time, this system can help us in delineating open water flood areas. In addition, identifying flood levels will enable effective disaster response and mitigation. If we combine the flood extent mapping with local topography, we can create a plan of action with downstream. We can use this information to predict the direction of flow of water, redirect flood waters, organize resources for distribution, etc. Such a
# system can also recommend a path of least flood levels in real-time that disaster response professionals can potentially adopt.

# %% [markdown]
# <a name='s1-2'></a>
# ## Deep Learning Model Training Workflow ##
# Building a deep learning model consists of several steps, including collecting large, high-quality data sets, preparing the data, training the model, and optimizing the model for deployment. When we train a neural network model with supervised learning, we leverage its ability to perform automatic feature extraction from raw data and associate them to our target. Generally, deep learning model performance increases when we train with more data, but the process is time consuming and computationally intensive. Once a model is trained, it can be deployed and used for inference. The model can be further fine-tuned and optimized to deliver the right level of accuracy and performance.
# <p><img src='images/model_training_workflow.png' width=720></p>

# %% [markdown]
# <a name='s1-2.1'></a>
# ### Deep Learning Challenges ###
# There are some common challenges related to developing deep learning-based solutions:
# * Training accurate deep learning models from scratch requires a large amount of data and acquiring them is a costly process since they need to be annotated, often manually
# * Development often requires knowledge of one or more deep learning frameworks, such as [TensorFlow](https://www.tensorflow.org/), [PyTorch](https://pytorch.org/), or [Caffe](https://caffe.berkeleyvision.org/)
# * Deep learning models require significant effort to fine-tune before it is optimized for inference and production ready
# * Processing data in real-time is computationally intensive and needs to be facilitated by software and hardware that enables low latency and high throughput
#
# As we will demonstrate, NVIDIA's [DALI](https://developer.nvidia.com/dali), [TAO Toolkit](https://developer.nvidia.com/tao), [TensorRT](https://developer.nvidia.com/tensorrt), and [Triton Inference Server](https://developer.nvidia.com/nvidia-triton-inference-server), can be used to tackle these challenges.

# %% [markdown]
# <a name='s1-3'></a>
# ## Introducing the Data Set ##

# %% [markdown]
# <a name='s1-3.1'></a>
# ### Sentinel-1 Data Public Access ###
# The Sentinel-1 SAR data we will use is available from [ESA](https://www.esa.int/) via the [Copernicus Open Access Hub](https://scihub.copernicus.eu/). They maintain an archive and is committed to delivering data within 24 hours of acquisition and maintains recent months of data. They are also available via NASA's [EARTHDATASEARCH](https://search.earthdata.nasa.gov/) or [Vertex](https://search.asf.alaska.edu/#/), Alaska Satellite Facility's data portal. They are organized as tiles, which is the process of subdividing geographic data into pre-defined roughly-squares. Tile-based mapping efficiently renders, stores, and retrieves image data.
# <p><img src='images/sentinel-1_capture.png' width=720></p>

# %% [markdown]
# <a name='s1-3.2'></a>
# ### Exploratory Data Analysis ###
# We have organized the `data` directory as below. For each image tile, there are three pieces of information: `image`, `mask`, and `catalog.json`. The catalog describes the meta data associated with the image such as the geographic coordinates boundaries (longitude, latitude) and timestamp. In addition, there is a `Sen1Floods11_Metadata.geojson` file that records the manifest by a specific region at a specific time.
#
# ```
# root@server:/data$ tree
# .
# ├── catalog
# │   └── sen1floods11_hand_labeled_source
# │       ├── region_1
# │       │   └── region_1.json
# │       ├── region_2
# │       │   └── region_2.json
# │
# ├── images
# │   └── all_images
# │       ├── region_1.png
# │       ├── region_2.png
# │
# ├── masks
# │   └── all_masks
# │       ├── region_1.png
# │       ├── region_2.png
# │
# └── Sen1Floods11_metadata.geojson
# ```
# <p><img src='images/input_and_mask.png' width=720></p>

# %% [markdown]
# First, we need to unzip the `flood_data.zip` file, which includes all our data. We can also count the number of images and masks to ensure they match.

# %%
# DO NOT CHANGE THIS CELL
# unzip data file
# !unzip data/flood_data.zip -d data
# Out:
# Archive:  data/flood_data.zip
#   inflating: data/Sen1Floods11_Metadata.geojson
#    creating: data/catalog/
#    creating: data/catalog/sen1floods11_hand_labeled_source/
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_953791/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_953791/Ghana_953791.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_210595/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_210595/Pakistan_210595.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_198411/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_198411/USA_198411.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_740461/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_740461/Pakistan_740461.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_401863/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_401863/Pakistan_401863.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_956740/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_956740/Sri-Lanka_956740.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_430764/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_430764/USA_430764.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_7856615/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_7856615/Spain_7856615.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_11745/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_11745/Ghana_11745.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_406026/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_406026/Ghana_406026.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_804466/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_804466/India_804466.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1029191/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1029191/Paraguay_1029191.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_177319/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_177319/India_177319.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_178753/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_178753/Sri-Lanka_178753.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_120804/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_120804/Sri-Lanka_120804.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_147015/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_147015/Ghana_147015.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_153941/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_153941/Paraguay_153941.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_249079/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_249079/Sri-Lanka_249079.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_265762/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_265762/India_265762.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_579082/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_579082/Sri-Lanka_579082.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1033830/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1033830/Ghana_1033830.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_264787/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_264787/Ghana_264787.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_314919/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_314919/Bolivia_314919.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_7370579/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_7370579/Spain_7370579.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_833266/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_833266/India_833266.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_989230/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_989230/Paraguay_989230.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1078550/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1078550/Ghana_1078550.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_528249/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_528249/Pakistan_528249.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1089161/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_1089161/Ghana_1089161.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_217598/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_217598/USA_217598.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_707886/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_707886/India_707886.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_866994/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_866994/Ghana_866994.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_921838/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_921838/Paraguay_921838.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_908474/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_908474/USA_908474.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_7496/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_7496/Ghana_7496.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_251323/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_251323/USA_251323.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_83483/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_83483/Ghana_83483.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_31559/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_31559/Sri-Lanka_31559.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_135434/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_135434/India_135434.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_67102/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_67102/USA_67102.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_764946/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_764946/India_764946.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_128663/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_128663/Ghana_128663.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_649376/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_649376/Somalia_649376.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_234935/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_234935/Ghana_234935.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_652955/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_652955/USA_652955.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_60373/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_60373/Bolivia_60373.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_308249/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_308249/Ghana_308249.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_604222/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_604222/USA_604222.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_194723/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_194723/Ghana_194723.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_36015/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_36015/Paraguay_36015.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_132143/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_132143/Pakistan_132143.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_233609/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_233609/Sri-Lanka_233609.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_495107/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_495107/Ghana_495107.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_56450/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_56450/India_56450.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_624341/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_624341/India_624341.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_324254/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_324254/India_324254.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_7604243/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_7604243/Spain_7604243.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_337094/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_337094/Spain_337094.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_952958/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_952958/Nigeria_952958.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1056717/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1056717/Paraguay_1056717.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_260929/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_260929/USA_260929.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_6860600/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_6860600/Spain_6860600.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_956930/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_956930/India_956930.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_600295/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_600295/Nigeria_600295.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_605682/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_605682/Paraguay_605682.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1019808/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_1019808/Paraguay_1019808.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_78061/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_78061/Nigeria_78061.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_124834/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_124834/Ghana_124834.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_482517/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_482517/Paraguay_482517.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_80102/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_80102/Paraguay_80102.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_293769/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_293769/Mekong_293769.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_25540/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_25540/India_25540.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_333434/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_333434/Mekong_333434.json
#   inflating: data/catalog/sen1floods11_hand_labeled_source/collection.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_5650136/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_5650136/Spain_5650136.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_943439/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_943439/India_943439.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_741178/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_741178/USA_741178.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_294583/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_294583/Bolivia_294583.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_366607/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_366607/USA_366607.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_79637/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_79637/India_79637.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_118868/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_118868/India_118868.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_790830/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_790830/Paraguay_790830.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_527077/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_527077/USA_527077.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_143329/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_143329/Nigeria_143329.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_132922/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_132922/Sri-Lanka_132922.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_167233/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_167233/Ghana_167233.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_172476/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_172476/Paraguay_172476.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_649970/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_649970/Sri-Lanka_649970.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_788696/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_788696/USA_788696.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_63307/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_63307/Sri-Lanka_63307.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_778194/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_778194/USA_778194.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_387945/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_387945/USA_387945.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_170264/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_170264/USA_170264.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_280900/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_280900/Paraguay_280900.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_822142/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_822142/Paraguay_822142.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_1038087/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_1038087/Sri-Lanka_1038087.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_236628/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_236628/Sri-Lanka_236628.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_382276/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_382276/Mekong_382276.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_5923267/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_5923267/Spain_5923267.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_399883/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_399883/India_399883.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_73419/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_73419/India_73419.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_693819/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_693819/USA_693819.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_225131/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_225131/Nigeria_225131.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_989553/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_989553/Somalia_989553.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_758178/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_758178/USA_758178.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1439641/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1439641/Mekong_1439641.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_191503/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_191503/Paraguay_191503.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_66026/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_66026/USA_66026.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_103757/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_103757/Bolivia_103757.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_49890/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_49890/Ghana_49890.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_76868/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_76868/Paraguay_76868.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_252217/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_252217/Paraguay_252217.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_59460/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_59460/India_59460.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_34417/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_34417/Paraguay_34417.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_205466/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_205466/Somalia_205466.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_246510/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_246510/Pakistan_246510.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_7558720/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_7558720/Spain_7558720.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_523539/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_523539/Sri-Lanka_523539.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_224165/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_224165/USA_224165.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_144050/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_144050/Ghana_144050.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_1068117/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_1068117/India_1068117.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_694942/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_694942/Pakistan_694942.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_3285448/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_3285448/Spain_3285448.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_97059/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_97059/Ghana_97059.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_44475/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_44475/India_44475.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_612594/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_612594/Sri-Lanka_612594.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_450918/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_450918/Sri-Lanka_450918.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_275372/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_275372/USA_275372.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_377277/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_377277/Sri-Lanka_377277.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_651904/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_651904/Paraguay_651904.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_149830/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_149830/Paraguay_149830.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_432776/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_432776/Bolivia_432776.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_205585/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_205585/Paraguay_205585.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_225187/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_225187/Paraguay_225187.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_605492/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_605492/USA_605492.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_391908/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_391908/India_391908.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_1087508/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_1087508/Somalia_1087508.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_11869/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_11869/Paraguay_11869.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_900498/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_900498/India_900498.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_970508/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_970508/Somalia_970508.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_336228/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_336228/Pakistan_336228.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_273873/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_273873/India_273873.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_22088/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_22088/Nigeria_22088.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_65724/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_65724/Pakistan_65724.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_148318/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_148318/Paraguay_148318.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_59731/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_59731/Paraguay_59731.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_895194/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_895194/Ghana_895194.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_847275/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_847275/Sri-Lanka_847275.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_826217/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_826217/USA_826217.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1111068/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1111068/Mekong_1111068.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_439488/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_439488/Nigeria_439488.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_592446/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_592446/India_592446.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_224845/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_224845/Paraguay_224845.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_11422/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_11422/USA_11422.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_2938657/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_2938657/Spain_2938657.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_806273/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_806273/USA_806273.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_8199661/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_8199661/Spain_8199661.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_1068362/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_1068362/USA_1068362.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_179238/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_179238/India_179238.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_812045/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_812045/Nigeria_812045.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_760290/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_760290/Pakistan_760290.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_45911/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_45911/Ghana_45911.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_887131/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_887131/Ghana_887131.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_350244/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_350244/USA_350244.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_319168/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_319168/Ghana_319168.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_1049830/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_1049830/Sri-Lanka_1049830.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_1018327/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_1018327/India_1018327.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_92824/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_92824/Sri-Lanka_92824.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_922192/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_922192/Sri-Lanka_922192.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_922373/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_922373/Mekong_922373.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_470303/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_470303/Paraguay_470303.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_795075/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_795075/Paraguay_795075.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_244057/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_244057/India_244057.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_97516/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_97516/Ghana_97516.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_1010394/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_1010394/USA_1010394.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_886726/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_886726/Somalia_886726.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_1039203/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_1039203/USA_1039203.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_529525/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_529525/Nigeria_529525.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_126224/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_126224/Paraguay_126224.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_179917/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_179917/USA_179917.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_284928/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_284928/Paraguay_284928.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_747992/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_747992/India_747992.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_187318/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_187318/Ghana_187318.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_909806/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_909806/Pakistan_909806.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_181503/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_181503/USA_181503.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_1068756/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_1068756/Somalia_1068756.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_8154154/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_8154154/Spain_8154154.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_81933/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_81933/Nigeria_81933.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_14484/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_14484/Sri-Lanka_14484.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_26376/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_26376/Ghana_26376.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_657443/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_657443/Paraguay_657443.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_7387658/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_7387658/Spain_7387658.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_769408/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_769408/India_769408.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_246718/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_246718/Pakistan_246718.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_295782/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_295782/Somalia_295782.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_366265/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_366265/Pakistan_366265.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_362274/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_362274/Ghana_362274.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_211406/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_211406/USA_211406.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_648632/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_648632/Paraguay_648632.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_93023/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_93023/Somalia_93023.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_747970/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_747970/India_747970.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_101973/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_101973/Sri-Lanka_101973.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_685158/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_685158/Somalia_685158.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_596495/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_596495/Mekong_596495.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_179624/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_179624/Paraguay_179624.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1191208/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1191208/Mekong_1191208.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_712873/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_712873/Pakistan_712873.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_354981/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_354981/USA_354981.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_230192/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_230192/Somalia_230192.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_716716/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_716716/Spain_716716.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_322855/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_322855/Somalia_322855.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_141271/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_141271/Ghana_141271.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_141910/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_141910/Ghana_141910.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_161233/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_161233/Ghana_161233.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_933610/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_933610/USA_933610.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_132163/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_132163/Ghana_132163.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_305760/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_305760/Paraguay_305760.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_2472849/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_2472849/Spain_2472849.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_591317/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_591317/India_591317.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_741073/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_741073/USA_741073.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_313799/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_313799/Ghana_313799.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_136196/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_136196/India_136196.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_277/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_277/Ghana_277.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_486103/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_486103/USA_486103.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_52610/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_52610/Mekong_52610.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_438959/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_438959/USA_438959.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_1072277/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_1072277/India_1072277.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_979278/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_979278/India_979278.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_70625/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_70625/Pakistan_70625.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_55568/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_55568/Sri-Lanka_55568.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_997480/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_997480/Paraguay_997480.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_215904/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_215904/Paraguay_215904.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_519181/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_519181/USA_519181.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_770353/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_770353/USA_770353.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_31096/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_31096/Nigeria_31096.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_35915/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_35915/Pakistan_35915.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_638521/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_638521/USA_638521.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_80221/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_80221/India_80221.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_664261/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_664261/USA_664261.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_1167260/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_1167260/Spain_1167260.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_916628/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_916628/Sri-Lanka_916628.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_166709/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_166709/India_166709.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_91379/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_91379/India_91379.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1248200/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1248200/Mekong_1248200.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1149855/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_1149855/Mekong_1149855.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_53713/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_53713/Ghana_53713.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_1082482/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_1082482/USA_1082482.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_44682/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_44682/Paraguay_44682.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_474783/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_474783/Mekong_474783.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_321316/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_321316/Sri-Lanka_321316.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_896458/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_896458/Paraguay_896458.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_5678382/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_5678382/Spain_5678382.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_287642/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_287642/India_287642.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_269835/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_269835/Mekong_269835.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_114964/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_114964/USA_114964.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_168875/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_168875/Ghana_168875.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_8372658/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_8372658/Spain_8372658.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_849649/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Sri-Lanka_849649/Sri-Lanka_849649.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_6199994/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_6199994/Spain_6199994.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_7931/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_7931/Somalia_7931.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_348639/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_348639/USA_348639.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Spain_2594119/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Spain_2594119/Spain_2594119.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_1049586/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_1049586/USA_1049586.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_62897/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_62897/Paraguay_62897.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_846007/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_846007/Mekong_846007.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_383430/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_383430/India_383430.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Ghana_24858/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Ghana_24858/Ghana_24858.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_54421/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_54421/Paraguay_54421.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_667363/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Pakistan_667363/Pakistan_667363.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_664410/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_664410/India_664410.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_271769/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_271769/Paraguay_271769.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_242570/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Bolivia_242570/Bolivia_242570.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_32375/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_32375/Somalia_32375.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_403081/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_403081/Paraguay_403081.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Mekong_45934/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Mekong_45934/Mekong_45934.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_1018317/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_1018317/India_1018317.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_992457/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_992457/Somalia_992457.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_308150/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/USA_308150/USA_308150.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_698338/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_698338/India_698338.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_180633/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_180633/India_180633.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_721886/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Paraguay_721886/Paraguay_721886.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_195014/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_195014/Somalia_195014.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Somalia_167787/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Somalia_167787/Somalia_167787.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_707067/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/Nigeria_707067/Nigeria_707067.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/India_1050276/
#   inflating: data/catalog/sen1floods11_hand_labeled_source/India_1050276/India_1050276.json
#    creating: data/catalog/sen1floods11_hand_labeled_source/USA_225017/
# ...
#   inflating: data/masks/all_masks/Paraguay_913449.png
#   inflating: data/masks/all_masks/Paraguay_198534.png
#   inflating: data/masks/all_masks/Nigeria_35845.png
#   inflating: data/masks/all_masks/Spain_6095801.png
#   inflating: data/masks/all_masks/USA_994009.png
#   inflating: data/masks/all_masks/Somalia_371421.png
#  extracting: data/masks/all_masks/India_500266.png
#   inflating: data/masks/all_masks/Somalia_60129.png
#   inflating: data/masks/all_masks/Paraguay_24341.png
#   inflating: data/masks/all_masks/Nigeria_417184.png
#   inflating: data/masks/all_masks/Bolivia_76104.png
#   inflating: data/masks/all_masks/Pakistan_43105.png
#   inflating: data/masks/all_masks/Paraguay_212687.png
#   inflating: data/masks/all_masks/Mekong_1395593.png
#   inflating: data/masks/all_masks/USA_58086.png
#   inflating: data/masks/all_masks/Sri-Lanka_400518.png
#  extracting: data/masks/all_masks/USA_955053.png
#   inflating: data/masks/all_masks/Ghana_134751.png
#  extracting: data/masks/all_masks/India_1017769.png
#  extracting: data/masks/all_masks/Mekong_774566.png
#   inflating: data/masks/all_masks/USA_84195.png
#   inflating: data/masks/all_masks/USA_375183.png
#   inflating: data/masks/all_masks/Spain_2523247.png
#   inflating: data/masks/all_masks/Mekong_213094.png
#   inflating: data/masks/all_masks/India_828067.png
#   inflating: data/masks/all_masks/Ghana_5079.png
#   inflating: data/masks/all_masks/USA_905409.png
#  extracting: data/masks/all_masks/Bolivia_379434.png
#   inflating: data/masks/all_masks/USA_831672.png
#   inflating: data/masks/all_masks/Bolivia_195474.png
#   inflating: data/masks/all_masks/Paraguay_511199.png
#   inflating: data/masks/all_masks/Somalia_256539.png
#   inflating: data/masks/all_masks/Sri-Lanka_748447.png
#   inflating: data/masks/all_masks/Pakistan_1036366.png
#   inflating: data/masks/all_masks/Paraguay_12870.png
#   inflating: data/masks/all_masks/Paraguay_683296.png
#   inflating: data/masks/all_masks/India_164336.png
#   inflating: data/masks/all_masks/Ghana_83200.png
#   inflating: data/masks/all_masks/Paraguay_1029042.png
#  extracting: data/masks/all_masks/Bolivia_129334.png
#   inflating: data/masks/all_masks/Spain_1199913.png
#   inflating: data/masks/all_masks/Mekong_1443339.png
#   inflating: data/masks/all_masks/USA_19225.png
#   inflating: data/masks/all_masks/Somalia_166342.png
#   inflating: data/masks/all_masks/USA_66511.png
#   inflating: data/masks/all_masks/Spain_4915752.png
#   inflating: data/masks/all_masks/Ghana_142312.png
#   inflating: data/masks/all_masks/Bolivia_290290.png
#   inflating: data/masks/all_masks/Sri-Lanka_117737.png
#   inflating: data/masks/all_masks/Pakistan_1027214.png
#   inflating: data/masks/all_masks/India_534470.png
#   inflating: data/masks/all_masks/Sri-Lanka_534068.png
#   inflating: data/masks/all_masks/Ghana_154838.png
#   inflating: data/masks/all_masks/Spain_8104659.png
#   inflating: data/masks/all_masks/USA_761032.png
#   inflating: data/masks/all_masks/Nigeria_598959.png
#   inflating: data/masks/all_masks/India_869358.png
#   inflating: data/masks/all_masks/Sri-Lanka_85652.png
#   inflating: data/masks/all_masks/Paraguay_232281.png
#   inflating: data/masks/all_masks/Paraguay_892933.png
#   inflating: data/masks/all_masks/Paraguay_792268.png
#   inflating: data/masks/all_masks/Sri-Lanka_653336.png
#   inflating: data/masks/all_masks/India_533192.png
#  extracting: data/masks/all_masks/India_566697.png
#   inflating: data/masks/all_masks/Ghana_135389.png
#   inflating: data/masks/all_masks/Ghana_141910.png
#   inflating: data/masks/all_masks/Somalia_322855.png
#   inflating: data/masks/all_masks/Ghana_141271.png
#   inflating: data/masks/all_masks/Ghana_132163.png
#   inflating: data/masks/all_masks/USA_933610.png
#   inflating: data/masks/all_masks/Ghana_161233.png
#   inflating: data/masks/all_masks/India_591317.png
#   inflating: data/masks/all_masks/USA_741073.png
#   inflating: data/masks/all_masks/Spain_2472849.png
#  extracting: data/masks/all_masks/Paraguay_305760.png
#   inflating: data/masks/all_masks/Ghana_313799.png
#   inflating: data/masks/all_masks/India_136196.png
#  extracting: data/masks/all_masks/India_1072277.png
#   inflating: data/masks/all_masks/USA_438959.png
#   inflating: data/masks/all_masks/USA_486103.png
#   inflating: data/masks/all_masks/Ghana_277.png
#  extracting: data/masks/all_masks/Mekong_52610.png
#   inflating: data/masks/all_masks/Sri-Lanka_55568.png
#   inflating: data/masks/all_masks/India_979278.png
#   inflating: data/masks/all_masks/Pakistan_70625.png
#   inflating: data/masks/all_masks/Paraguay_215904.png
#   inflating: data/masks/all_masks/Paraguay_997480.png
#   inflating: data/masks/all_masks/Sri-Lanka_101973.png
#   inflating: data/masks/all_masks/India_747970.png
#   inflating: data/masks/all_masks/Somalia_93023.png
#   inflating: data/masks/all_masks/Mekong_1191208.png
#   inflating: data/masks/all_masks/Paraguay_179624.png
#   inflating: data/masks/all_masks/Pakistan_712873.png
#   inflating: data/masks/all_masks/Somalia_685158.png
#  extracting: data/masks/all_masks/Mekong_596495.png
#   inflating: data/masks/all_masks/Somalia_230192.png
#   inflating: data/masks/all_masks/Spain_716716.png
#   inflating: data/masks/all_masks/USA_354981.png
#   inflating: data/masks/all_masks/Pakistan_366265.png
#   inflating: data/masks/all_masks/Pakistan_246718.png
#   inflating: data/masks/all_masks/Somalia_295782.png
#   inflating: data/masks/all_masks/India_769408.png
#   inflating: data/masks/all_masks/Ghana_362274.png
#   inflating: data/masks/all_masks/Paraguay_648632.png
#   inflating: data/masks/all_masks/USA_211406.png
#  extracting: data/masks/all_masks/Spain_7387658.png
#   inflating: data/masks/all_masks/Paraguay_657443.png
#   inflating: data/masks/all_masks/Ghana_26376.png
#   inflating: data/masks/all_masks/Spain_8154154.png
#   inflating: data/masks/all_masks/Somalia_1068756.png
#  extracting: data/masks/all_masks/Nigeria_81933.png
#   inflating: data/masks/all_masks/Sri-Lanka_14484.png
#   inflating: data/masks/all_masks/Pakistan_65724.png
#   inflating: data/masks/all_masks/Nigeria_439488.png
#  extracting: data/masks/all_masks/Mekong_1111068.png
#   inflating: data/masks/all_masks/USA_826217.png
#  extracting: data/masks/all_masks/Sri-Lanka_847275.png
#   inflating: data/masks/all_masks/Ghana_895194.png
#   inflating: data/masks/all_masks/Paraguay_148318.png
#   inflating: data/masks/all_masks/Paraguay_59731.png
#   inflating: data/masks/all_masks/Spain_8199661.png
#   inflating: data/masks/all_masks/USA_1068362.png
#   inflating: data/masks/all_masks/Spain_2938657.png
#   inflating: data/masks/all_masks/USA_806273.png
#   inflating: data/masks/all_masks/USA_11422.png
#   inflating: data/masks/all_masks/Paraguay_224845.png
#   inflating: data/masks/all_masks/India_592446.png
#   inflating: data/masks/all_masks/Ghana_45911.png
#   inflating: data/masks/all_masks/Pakistan_760290.png
#   inflating: data/masks/all_masks/Nigeria_812045.png
#  extracting: data/masks/all_masks/India_179238.png
#   inflating: data/masks/all_masks/India_273873.png
#   inflating: data/masks/all_masks/Pakistan_336228.png
#  extracting: data/masks/all_masks/India_900498.png
#   inflating: data/masks/all_masks/Paraguay_11869.png
#  extracting: data/masks/all_masks/Somalia_970508.png
#   inflating: data/masks/all_masks/Nigeria_22088.png
#   inflating: data/masks/all_masks/Bolivia_432776.png
#   inflating: data/masks/all_masks/Paraguay_225187.png
#   inflating: data/masks/all_masks/Paraguay_205585.png
#   inflating: data/masks/all_masks/Somalia_1087508.png
#   inflating: data/masks/all_masks/India_391908.png
#   inflating: data/masks/all_masks/USA_605492.png
#   inflating: data/masks/all_masks/Paraguay_149830.png
#   inflating: data/masks/all_masks/USA_275372.png
#   inflating: data/masks/all_masks/Sri-Lanka_377277.png
#   inflating: data/masks/all_masks/Paraguay_651904.png
#   inflating: data/masks/all_masks/USA_1039203.png
#   inflating: data/masks/all_masks/Nigeria_529525.png
#  extracting: data/masks/all_masks/Somalia_886726.png
#   inflating: data/masks/all_masks/USA_1010394.png
#   inflating: data/masks/all_masks/Ghana_97516.png
#   inflating: data/masks/all_masks/USA_179917.png
#  extracting: data/masks/all_masks/Paraguay_126224.png
#   inflating: data/masks/all_masks/Paraguay_284928.png
#   inflating: data/masks/all_masks/Ghana_187318.png
#   inflating: data/masks/all_masks/USA_181503.png
#   inflating: data/masks/all_masks/Pakistan_909806.png
#  extracting: data/masks/all_masks/India_747992.png
#  extracting: data/masks/all_masks/Mekong_922373.png
#   inflating: data/masks/all_masks/Sri-Lanka_922192.png
#   inflating: data/masks/all_masks/Paraguay_795075.png
#   inflating: data/masks/all_masks/India_244057.png
#   inflating: data/masks/all_masks/Paraguay_470303.png
#  extracting: data/masks/all_masks/Sri-Lanka_92824.png
#   inflating: data/masks/all_masks/Sri-Lanka_1049830.png
#  extracting: data/masks/all_masks/India_1018327.png
#   inflating: data/masks/all_masks/Ghana_319168.png
#   inflating: data/masks/all_masks/Ghana_887131.png
#   inflating: data/masks/all_masks/USA_350244.png
#   inflating: data/masks/all_masks/India_177319.png
#   inflating: data/masks/all_masks/Paraguay_1029191.png
#   inflating: data/masks/all_masks/Sri-Lanka_249079.png
#   inflating: data/masks/all_masks/India_265762.png
#   inflating: data/masks/all_masks/Paraguay_153941.png
#   inflating: data/masks/all_masks/Sri-Lanka_120804.png
#   inflating: data/masks/all_masks/Sri-Lanka_178753.png
#   inflating: data/masks/all_masks/Ghana_147015.png
#   inflating: data/masks/all_masks/Sri-Lanka_579082.png
#   inflating: data/masks/all_masks/Ghana_1033830.png
#  extracting: data/masks/all_masks/Bolivia_314919.png
#   inflating: data/masks/all_masks/Ghana_264787.png
#  extracting: data/masks/all_masks/Spain_7370579.png
#  extracting: data/masks/all_masks/India_833266.png
#   inflating: data/masks/all_masks/USA_430764.png
#   inflating: data/masks/all_masks/Sri-Lanka_956740.png
#   inflating: data/masks/all_masks/Spain_7856615.png
#   inflating: data/masks/all_masks/Ghana_406026.png
#  extracting: data/masks/all_masks/India_804466.png
#   inflating: data/masks/all_masks/Ghana_11745.png
#   inflating: data/masks/all_masks/Pakistan_401863.png
#   inflating: data/masks/all_masks/USA_198411.png
#   inflating: data/masks/all_masks/Pakistan_740461.png
#   inflating: data/masks/all_masks/Pakistan_210595.png
#   inflating: data/masks/all_masks/Ghana_953791.png
#   inflating: data/masks/all_masks/USA_67102.png
#   inflating: data/masks/all_masks/India_764946.png
#   inflating: data/masks/all_masks/Ghana_234935.png
#   inflating: data/masks/all_masks/Somalia_649376.png
#   inflating: data/masks/all_masks/Ghana_128663.png
#   inflating: data/masks/all_masks/Bolivia_60373.png
#   inflating: data/masks/all_masks/Ghana_308249.png
#   inflating: data/masks/all_masks/USA_604222.png
#   inflating: data/masks/all_masks/USA_652955.png
#   inflating: data/masks/all_masks/Paraguay_36015.png
#   inflating: data/masks/all_masks/Pakistan_132143.png
#   inflating: data/masks/all_masks/Ghana_194723.png
#   inflating: data/masks/all_masks/Ghana_495107.png
#   inflating: data/masks/all_masks/Sri-Lanka_233609.png
#   inflating: data/masks/all_masks/India_324254.png
#   inflating: data/masks/all_masks/India_624341.png
#   inflating: data/masks/all_masks/India_56450.png
#   inflating: data/masks/all_masks/Ghana_7496.png
#   inflating: data/masks/all_masks/USA_908474.png
#   inflating: data/masks/all_masks/Sri-Lanka_31559.png
#   inflating: data/masks/all_masks/Ghana_83483.png
#   inflating: data/masks/all_masks/USA_251323.png
#   inflating: data/masks/all_masks/India_135434.png
#   inflating: data/masks/all_masks/India_707886.png
#   inflating: data/masks/all_masks/USA_217598.png
#   inflating: data/masks/all_masks/Paraguay_921838.png
#   inflating: data/masks/all_masks/Ghana_866994.png
#   inflating: data/masks/all_masks/Ghana_1089161.png
#   inflating: data/masks/all_masks/Pakistan_528249.png
#   inflating: data/masks/all_masks/Ghana_1078550.png
#   inflating: data/masks/all_masks/Paraguay_989230.png
#   inflating: data/masks/all_masks/India_25540.png
#   inflating: data/masks/all_masks/Mekong_333434.png
#   inflating: data/masks/all_masks/Spain_5650136.png
#  extracting: data/masks/all_masks/India_943439.png
#   inflating: data/masks/all_masks/USA_741178.png
#   inflating: data/masks/all_masks/Bolivia_294583.png
#   inflating: data/masks/all_masks/USA_366607.png
#   inflating: data/masks/all_masks/India_79637.png
#   inflating: data/masks/all_masks/India_118868.png
#   inflating: data/masks/all_masks/Paraguay_790830.png
#   inflating: data/masks/all_masks/USA_527077.png
#   inflating: data/masks/all_masks/Nigeria_143329.png
#   inflating: data/masks/all_masks/Sri-Lanka_132922.png
#   inflating: data/masks/all_masks/Paraguay_172476.png
#   inflating: data/masks/all_masks/Ghana_167233.png
#  extracting: data/masks/all_masks/Sri-Lanka_649970.png
#   inflating: data/masks/all_masks/Sri-Lanka_63307.png
#   inflating: data/masks/all_masks/USA_788696.png
#   inflating: data/masks/all_masks/Paraguay_1019808.png
#  extracting: data/masks/all_masks/Paraguay_605682.png
#   inflating: data/masks/all_masks/Nigeria_78061.png
#   inflating: data/masks/all_masks/Ghana_124834.png
#   inflating: data/masks/all_masks/Paraguay_80102.png
#   inflating: data/masks/all_masks/Paraguay_482517.png
#   inflating: data/masks/all_masks/Mekong_293769.png
#   inflating: data/masks/all_masks/USA_260929.png
#   inflating: data/masks/all_masks/Spain_6860600.png
#  extracting: data/masks/all_masks/India_956930.png
#   inflating: data/masks/all_masks/Nigeria_600295.png
#   inflating: data/masks/all_masks/Paraguay_1056717.png
#   inflating: data/masks/all_masks/Nigeria_952958.png
#   inflating: data/masks/all_masks/Spain_337094.png
#   inflating: data/masks/all_masks/Spain_7604243.png
#   inflating: data/masks/all_masks/Ghana_49890.png
#   inflating: data/masks/all_masks/Bolivia_103757.png
#   inflating: data/masks/all_masks/Paraguay_252217.png
#   inflating: data/masks/all_masks/Paraguay_76868.png
#   inflating: data/masks/all_masks/India_59460.png
#   inflating: data/masks/all_masks/Paraguay_34417.png
#   inflating: data/masks/all_masks/Somalia_205466.png
#   inflating: data/masks/all_masks/Pakistan_246510.png
#   inflating: data/masks/all_masks/Spain_7558720.png
#  extracting: data/masks/all_masks/Sri-Lanka_523539.png
#   inflating: data/masks/all_masks/USA_224165.png
#   inflating: data/masks/all_masks/Ghana_144050.png
#  extracting: data/masks/all_masks/India_1068117.png
#   inflating: data/masks/all_masks/Pakistan_694942.png
#   inflating: data/masks/all_masks/Spain_3285448.png
#   inflating: data/masks/all_masks/Ghana_97059.png
#   inflating: data/masks/all_masks/India_44475.png
#   inflating: data/masks/all_masks/Sri-Lanka_612594.png
#   inflating: data/masks/all_masks/Sri-Lanka_450918.png
#  extracting: data/masks/all_masks/Sri-Lanka_1038087.png
#   inflating: data/masks/all_masks/Sri-Lanka_236628.png
#   inflating: data/masks/all_masks/Mekong_382276.png
#  extracting: data/masks/all_masks/India_399883.png
#   inflating: data/masks/all_masks/Spain_5923267.png
#   inflating: data/masks/all_masks/India_73419.png
#   inflating: data/masks/all_masks/USA_693819.png
#   inflating: data/masks/all_masks/Nigeria_225131.png
#   inflating: data/masks/all_masks/Somalia_989553.png
#   inflating: data/masks/all_masks/Mekong_1439641.png
#   inflating: data/masks/all_masks/USA_758178.png
#   inflating: data/masks/all_masks/Paraguay_191503.png
#   inflating: data/masks/all_masks/USA_66026.png
#   inflating: data/masks/all_masks/Paraguay_280900.png
#  extracting: data/masks/all_masks/Paraguay_822142.png
#   inflating: data/masks/all_masks/USA_387945.png
#   inflating: data/masks/all_masks/USA_170264.png
#   inflating: data/masks/all_masks/USA_778194.png

# %%
# DO NOT CHANGE THIS CELL
# import dependencies
import os
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec

# set environment variables
# %set_env LOCAL_DATA_DIR=/dli/task/data

# set paths for images and masks
image_dir=os.path.join(os.getenv('LOCAL_DATA_DIR'), 'images')
mask_dir=os.path.join(os.getenv('LOCAL_DATA_DIR'), 'masks')
# Out:
# env: LOCAL_DATA_DIR=/dli/task/data

# %%
# DO NOT CHANGE THIS CELL
# define function to count number of images per region
def count_num_images(file_dir): 
    """
    This function returns a dictionary representing the count of images for each region as the key. 
    """
    # list all files in the directory
    file_list=os.listdir(file_dir)
    region_count={}
    # iterate through the file_list and count by region
    for file_name in file_list: 
        region=file_name.split('_')[0]
        if (len(file_name.split('.'))==2) and (region in region_count): 
            region_count[region]+=1
        elif len(file_name.split('.'))==2: 
            region_count[region]=1
    return region_count

# %%
# DO NOT CHANGE THIS CELL
# count images and masks by region
images_count=count_num_images(os.path.join(image_dir, 'all_images'))
masks_count=count_num_images(os.path.join(mask_dir, 'all_masks'))

# display counts
print(f'-----number of images: {sum(images_count.values())}-----')
display(sorted(images_count.items(), key=lambda x: x[1]))

print(f'-----number of masks: {sum(masks_count.values())}-----')
display(sorted(masks_count.items(), key=lambda x: x[1]))
# Out:
# -----number of images: 446-----
# [('Bolivia', 15),
#  ('Nigeria', 18),
#  ('Somalia', 26),
#  ('Pakistan', 28),
#  ('Spain', 30),
#  ('Mekong', 30),
#  ('Sri-Lanka', 42),
#  ('Ghana', 53),
#  ('Paraguay', 67),
#  ('India', 68),
#  ('USA', 69)]
# -----number of masks: 446-----
# [('Bolivia', 15),
#  ('Nigeria', 18),
#  ('Somalia', 26),
#  ('Pakistan', 28),
#  ('Spain', 30),
#  ('Mekong', 30),
#  ('Sri-Lanka', 42),
#  ('Ghana', 53),
#  ('Paraguay', 67),
#  ('India', 68),
#  ('USA', 69)]

# %% [markdown]
# <a name='s1-e1'></a>
# ### Exercise #1 - Count Input Data ###
# Let's count the number of images in our training data set.
#
# **Instructions**:<br>
# * Modify the `<FIXME>` only to the number of tiles in the data set.

# %% [raw]
# The total number of tiles is: <<<<FIXME>>>>

# %% [raw]
# The total number of tiles is: 446

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# Each image and mask are accompanied by a JSON file that documents its latitude and longitude. We can go through the manifest to get a sense of how our data is populated.

# %%
# DO NOT CHANGE THIS CELL
# define function to get coordinates from catalog
def get_coordinates(catalog_dir): 
    """
    This function returns a list of boundaries for every image as [[lon, lat], [lon, lat], [lon, lat], etc.] in the catalog. 
    """
    catalog_list=os.listdir(catalog_dir)
    all_coordinates=[]
    for catalog in catalog_list: 
        # check if it's a directory based on if file_name has an extension
        if len(catalog.split('.'))==1:
            catalog_path=f'{catalog_dir}/{catalog}/{catalog}.json'
            # read catalog
            with open(catalog_path) as f: 
                catalog_json=json.load(f)
            # parse out coordinates
            coordinates_list=catalog_json['geometry']['coordinates'][0]
            lon=[coordinates[0] for coordinates in coordinates_list]
            all_coordinates.append(lon)
            lat=[coordinates[1] for coordinates in coordinates_list]
            all_coordinates.append(lat)
    return all_coordinates

# %%
# DO NOT CHANGE THIS CELL
# set paths for images catalog
image_catalog_dir=os.path.join(os.getenv('LOCAL_DATA_DIR'), 'catalog', 'sen1floods11_hand_labeled_source')
image_coordinates_list=get_coordinates(image_catalog_dir)

# flatten lat and lon coordinate lists
image_lon=[image_coordinates_list[x] for x in range(len(image_coordinates_list)) if x%2==0]
image_lon=np.concatenate(image_lon).ravel()
image_lat=[image_coordinates_list[x] for x in range(len(image_coordinates_list)) if x%2==1]
image_lat=np.concatenate(image_lat).ravel()

plt.figure(figsize=(15, 5))

plt.scatter(image_lon, image_lat)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Training Data Distribution')
plt.xlim([-100, 110])
plt.ylim([-30, 45])
plt.show()

# %% [markdown]
# <p><img src='images/check.png' width=720></p>
# Out of the entire Earth, we only have a small number of tiles available.

# %% [markdown]
# Let's now take a look at the specific areas. We have provided three helper functions `get_extent(file_path)`,  `tiles_by_country(country_name, image_type)` and `tiles_by_bound(top_left, bottom_right, image_type)`, where `image_type` is either `masks` or `images`.

# %%
# DO NOT CHANGE THIS CELL
# define function to get extent of an image from catalog
def get_extent(file_path): 
    """
    This function returns the extent as [left, right, bottom, top] for a given image. 
    """
    # read catalog for image
    with open(file_path) as f: 
        catalog_json=json.load(f)
    coordinates=catalog_json['geometry']['coordinates'][0]
    coordinates=np.array(coordinates)
    # get boundaries
    left=np.min(coordinates[:, 0])
    right=np.max(coordinates[:, 0])
    bottom=np.min(coordinates[:, 1])
    top=np.max(coordinates[:, 1])
    return left, right, bottom, top

# %%
# DO NOT CHANGE THIS CELL
# define function to plot by region
def tiles_by_region(country_name, plot_type='images'): 
    # set catalog and images/masks path
    catalog_dir=os.path.join(os.getenv('LOCAL_DATA_DIR'), 'catalog', 'sen1floods11_hand_labeled_source')
    if plot_type=='images': 
        dir=os.path.join(image_dir, 'all_images')
        cmap='viridis'
    elif plot_type=='masks': 
        dir=os.path.join(mask_dir, 'all_masks')
        cmap='gray'
    else: 
        raise Exception('Bad Plot Type')

    # initiate figure boundaries, which will be modified based on the extent of the tiles
    x_min, x_max, y_min, y_max=181, -181, 91, -91
    fig=plt.figure(figsize=(15, 15))
    ax=plt.subplot(111)
    
    # iterate through each image/mask and plot
    file_list=os.listdir(dir)
    for each_file in file_list:
        # check if image/mask is related to region and a .png file
        if (each_file.split('.')[-1]=='png') & (each_file.split('_')[0]==country_name): 
            # get boundaries of the image
            extent=get_extent(f"{catalog_dir}/{each_file.split('.')[0]}/{each_file.split('.')[0]}.json")
            x_min, x_max=min(extent[0], x_min), max(extent[1], x_max)
            y_min, y_max=min(extent[2], y_min), max(extent[3], y_max)
            image=mpimg.imread(f'{dir}/{each_file}')
            plt.imshow(image, extent=extent, cmap=cmap)
    
    # set boundaries of the axis
    ax.set_xlim([x_min, x_max])
    ax.set_ylim([y_min, y_max])
    plt.show()

# %%
# DO NOT CHANGE THIS CELL
# define function to plot by boundaries
def tiles_by_boundaries(top_left, bottom_right, plot_type='images'): 
    # set catalog and images/masks path
    catalog_dir=os.path.join(os.getenv('LOCAL_DATA_DIR'), 'catalog', 'sen1floods11_hand_labeled_source')
    if plot_type=='images': 
        dir=os.path.join(image_dir, 'all_images')
        cmap='viridis'
    elif plot_type=='masks': 
        dir=os.path.join(mask_dir, 'all_masks')
        cmap='gray'
    else: 
        raise Exception('Bad Plot Type')

    # initiate figure boundaries, which will be modified based on the extent of the tiles
    x_min, x_max, y_min, y_max=top_left[0], bottom_right[0], bottom_right[1], top_left[1]
    ax_x_min, ax_x_max, ax_y_min, ax_y_max=181, -181, 91, -91

    fig=plt.figure(figsize=(15, 15))
    ax=plt.subplot(111)

    # iterate through each image/mask and plot
    file_list=os.listdir(dir)
    for each_file in file_list: 
        # check if image/mask is a .png file
        if each_file.split('.')[-1]=='png': 
            # get boundaries of the image/mask
            extent=get_extent(f"{catalog_dir}/{each_file.split('.')[0]}/{each_file.split('.')[0]}.json")
            (left, right, bottom, top)=extent
            if (left>x_min) & (right<x_max) & (bottom>y_min) & (top<y_max):
                ax_x_min, ax_x_max=min(left, ax_x_min), max(right, ax_x_max)
                ax_y_min, ax_y_max=min(bottom, ax_y_min), max(top, ax_y_max)
                image=mpimg.imread(f'{dir}/{each_file}')
                plt.imshow(image, extent=extent, cmap=cmap)

    # set boundaries of the axis
    ax.set_xlim([ax_x_min, ax_x_max])
    ax.set_ylim([ax_y_min, ax_y_max])
    plt.show()

# %% [markdown]
# <a name='s1-e2'></a>
# ### Exercise #2 - Explore Tiles ###
# Let's explore the different tiles in our data set.
#
# **Instructions**:<br>
# * Modify the `<FIXME>`s only and execute the cell to explore the data set. The regions where we have data for are `Bolivia`, `Paraguay`, `Somalia`, `Sri-Lanka`, `Ghana`, `India`, `USA`, `Spain`, `Pakistan`, `Mekong`, `Nigeria`.
# * Modify the `<FIXME>`s only and execute the cell below to explore the data set.

# %%
tiles_by_region('<<<<FIXME>>>>', '<<<<FIXME>>>>')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 tiles_by_region('<<<<FIXME>>>>', '<<<<FIXME>>>>')
#
# Input In [8], in tiles_by_region(country_name, plot_type)
#      11     cmap='gray'
#      12 else:
# ---> 13     raise Exception('Bad Plot Type')
#      15 # initiate figure boundaries, which will be modified based on the extent of the tiles
#      16 x_min, x_max, y_min, y_max=181, -181, 91, -91
#
# Exception: Bad Plot Type

# %%
tiles_by_boundaries((<<<<FIXME>>>>, <<<<FIXME>>>>), (<<<<FIXME>>>>, <<<<FIXME>>>>), '<<<<FIXME>>>>')

# %% [raw]
# tiles_by_region('Spain', 'images')
# tiles_by_region('Spain', 'masks')
#
# tiles_by_boundaries((-0.966, 38.4), (-0.597, 38.0), 'images')
# tiles_by_boundaries((-0.966, 38.4), (-0.597, 38.0), 'masks')

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# <a name='s1-4'></a>
# ## Data Pre-processing With DALI ##
# Deep learning models require vast amounts of data to produce accurate predictions, and this need becomes more significant as models grow in size and complexity. Regardless of the model, some degree of pre-processing is required for training and inference. In computer vision applications, the pre-processing usually includes decoding, resizing, and normalizing to a standardized format accepted by the neural network. Data preprocessing for deep learning workloads has garnered little attention until recently, eclipsed by the tremendous computational resources required for training complex models. These pre-processing routines, often referred to as pipelines, are currently executed on the CPU using libraries such as OpenCV, Pillow. Today’s DL applications include complex, multi-stage data processing pipelines consisting of many serial operations. Relying on the CPU to handle these pipelines have become a bottleneck that limits performance and scalability.
# <p><img src='images/dali.png' width=720></p>
#
# The **NVIDIA Data Loading Library** (DALI) is a library for data loading and pre-processing to accelerate deep learning applications. It provides a collection of highly optimized building blocks for loading and processing image, video, and audio data. DALI addresses the problem of the CPU bottleneck by offloading data preprocessing to the GPU. In addition, it offers some powerful features:
# * DALI offers data processing primitives for a variety of deep learning applications. The supported input formats include most used image file formats.
# * DALI relies on its own execution engine, built to maximize the throughput of the input pipeline.
# * It can be used as a portable drop-in replacement for built-in data loaders and data iterators in popular deep learning frameworks.
# * Features such as prefetching, parallel execution, and batch processing are handled transparently for the user.
# * Different deep learning frameworks have multiple data pre-processing implementations, resulting in challenges such as portability of training and inference workflows, and code maintainability. Data processing pipelines implemented using DALI are portable because they can easily be retargeted to TensorFlow, PyTorch, MXNet and PaddlePaddle.
# * Often the pre-processing routines that are used for inference are like the ones used for training, therefore implementing both using the same tools can save you some boilerplate and code repetition.

# %% [markdown]
# <a name='s1-4.1'></a>
# ###  DALI Pipeline ###
# At the core of data processing with DALI lies the concept of a data processing `pipeline`. It is composed of multiple operations connected in a directed graph and contained in an object of class `nvidia.dali.Pipeline`. This class provides functions necessary for defining, building, and running data processing pipelines. Each operator in the pipeline typically gets one or more inputs, applies some kind of data processing, and produces one or more outputs. There are special kinds of operators that don’t take any inputs and produce outputs. Those special operators act like a data source – _readers_, _random number generators_ and _external source_ fall into this category.
#
# DALI offers CPU and GPU implementations for a wide range of processing operators. The availability of a CPU or GPU implementation depends on the nature of the operator. Make sure to check the documentation for an [up-to-date list of supported operations](https://docs.nvidia.com/deeplearning/dali/user-guide/docs/#operations), as it is expanded with every release. The easiest way to define a DALI pipeline is using the `pipeline_def` Python [decorator](https://peps.python.org/pep-0318/). To create a pipeline, we define a function where we instantiate and connect the desired operators and return the relevant outputs. Then just decorate it with `pipeline_def`. Let's start with defining a very simple pipeline, which will have two operators. The first operator is a file reader that discovers and loads files contained in a directory. The reader outputs both the contents of the files (in this case, PNGs) and the labels, which are inferred from the directory structure. The second operator is an [image decoder](https://docs.nvidia.com/deeplearning/dali/user-guide/docs/supported_ops.html#nvidia.dali.fn.decoders.image). Lastly, we return the image and label pairs. The easiest way to create a pipieline is by using the `pipeline_def` decorator. In the `simple_pipeline` function we define the operations to be performed and the flow of the computation between them. For more information about `pipeline_def` look to the [documentation](https://docs.nvidia.com/deeplearning/dali/user-guide/docs/pipeline.html?#nvidia.dali.pipeline_def).

# %%
# DO NOT CHANGE THIS CELL
# import dependencies
from nvidia.dali.pipeline import Pipeline
from nvidia.dali import pipeline_def
import nvidia.dali.fn as fn
import nvidia.dali.types as types

import warnings
warnings.filterwarnings("ignore")

# %%
# DO NOT CHANGE THIS CELL
batch_size=4

@pipeline_def
def simple_pipeline():
    # use fn.readers.file to read encoded images and labels from the hard drive
    pngs, labels=fn.readers.file(file_root=image_dir)
    # use the fn.decoders.image operation to decode images from png to RGB
    images=fn.decoders.image(pngs, device='cpu')
    # specify which of the intermediate variables should be returned as the outputs of the pipeline
    return images, labels

# %% [markdown]
# In order to use the pipeline defined with `simple_pipeline`, we need to create and build it. This is achieved by calling `simple_pipeline()`, which creates an instance of the pipeline. Then we call `build()` on this newly created instance:

# %%
# DO NOT CHANGE THIS CELL
# create and build pipeline
pipe=simple_pipeline(batch_size=batch_size, num_threads=4, device_id=0)
pipe.build()

# %% [markdown]
# <p><img src='images/important.png' width=720></p>
#
# Notice that decorating a function with `pipeline_def` adds new named arguments to it. They can be used to control various aspects of the pipeline, such as batch size, number of threads used to perform computation on the CPU, and which GPU device to use (though pipeline created with simple_pipeline does not yet use GPU for compute). For more information about `Pipeline` arguments you can look to [Pipeline documentation](https://docs.nvidia.com/deeplearning/dali/user-guide/docs/pipeline.html).

# %% [markdown]
# Once built, a pipeline instance runs in an [asynchronous](https://en.wikipedia.org/wiki/Asynchrony_(computer_programming)) fashion by calling the pipeline's `run()` method to get a batch of results. We unpack the results into `images` and `labels` as expected. Both of these elements contain a list of tensors.

# %%
# DO NOT CHANGE THIS CELL
# run the pipeline
simple_pipe_output=pipe.run()

images, labels=simple_pipe_output
print("Images is_dense_tensor: " + str(images.is_dense_tensor()))
print("Labels is_dense_tensor: " + str(labels.is_dense_tensor()))
# Out:
# Images is_dense_tensor: True
# Labels is_dense_tensor: True

# %% [markdown]
# In order to see the images, we will need to loop over all tensors contained in `TensorList`, accessed with its `at` method.

# %%
# DO NOT CHANGE THIS CELL
# define a function display images
def show_images(image_batch):
    columns=4
    rows=1
    # create plot
    fig=plt.figure(figsize=(15, (15 // columns) * rows))
    gs=gridspec.GridSpec(rows, columns)
    for idx in range(rows*columns):
        plt.subplot(gs[idx])
        plt.axis("off")
        plt.imshow(image_batch.at(idx))
    plt.tight_layout()

show_images(images)

# %% [markdown]
# <a name='s1-4.2'></a>
# ### Data Augmentation ###
# Deep learning models require training with vast amounts of data to achieve accurate results. DALI can not only read images from disk and batch them into tensors, it can also perform various augmentations on those images to improve deep learning training results. [Data augmentation](https://en.wikipedia.org/wiki/Data_augmentation) artificially increases the size of a data set by introducing random disturbances to the data, such as _geometric deformations_, _color transforms_, _noise addition_, and so on. These disturbances help produce models that are more robust in their predictions, avoid overfitting, and deliver better accuracy. We will use DALI to demonstrate data augmentation that we will introduce for model training, such as _cropping_, _resizing_, and _flipping_.

# %%
# DO NOT CHANGE THIS CELL
import random

@pipeline_def
def augmentation_pipeline():
    # use fn.readers.file to read encoded images and labels from the hard drive
    image_pngs, _=fn.readers.file(file_root=image_dir)
    # use the fn.decoders.image operation to decode images from png to RGB
    images=fn.decoders.image(image_pngs, device='cpu')
    
    # the same augmentation needs to be performed on the associated masks
    mask_pngs, _=fn.readers.file(file_root=mask_dir)
    masks=fn.decoders.image(mask_pngs, device='cpu')
    
    image_size=512
    roi_size=image_size*.5
    roi_start_x=image_size*random.uniform(0, 0.5)
    roi_start_y=image_size*random.uniform(0, 0.5)
    
    # use fn.resize to investigate an roi, region of interest
    resized_images=fn.resize(images, size=[512, 512], roi_start=[roi_start_x, roi_start_y], roi_end=[roi_start_x+roi_size, roi_start_y+roi_size])
    resized_masks=fn.resize(masks, size=[512, 512], roi_start=[roi_start_x, roi_start_y], roi_end=[roi_start_x+roi_size, roi_start_y+roi_size])
    
    # use fn.resize to flip the image
    flipped_images=fn.resize(images, size=[-512, -512])
    flipped_masks=fn.resize(masks, size=[-512, -512])
    return images, resized_images, flipped_images, masks, resized_masks, flipped_masks

# %%
# DO NOT CHANGE THIS CELL
pipe=augmentation_pipeline(batch_size=batch_size, num_threads=4, device_id=0)
pipe.build()
augmentation_pipe_output=pipe.run()

# %%
# DO NOT CHANGE THIS CELL
# define a function display images
def show_augmented_images(pipe_output):
    image_batch, resized_image_batch, flipped_image_batch, mask_batch, resized_mask_batch, flipped_mask_batch=pipe_output
    columns=6
    rows=batch_size
    # create plot
    fig=plt.figure(figsize=(15, (15 // columns) * rows))
    gs=gridspec.GridSpec(rows, columns)
    grid_data=[image_batch, resized_image_batch, flipped_image_batch, mask_batch, resized_mask_batch, flipped_mask_batch]
    grid=0
    for row_idx in range(rows): 
        for col_idx in range(columns): 
            plt.subplot(gs[grid])
            plt.axis('off')
            plt.imshow(grid_data[col_idx].at(row_idx))
            grid+=1
    plt.tight_layout()

# %%
# DO NOT CHANGE THIS CELL
show_augmented_images(augmentation_pipe_output)

# %% [markdown]
# <a name='s1-e3'></a>
# ### Exercise #3 - Data Augmentation on Batch ###
# Let's perform data augmentation on more batches of data.
#
# **Instructions**:<br>
# * Execute the cell to run the pipeline on the (next) batch of data.

# %%
# DO NOT CHANGE THIS CELL
show_augmented_images(pipe.run())

# %% [markdown]
# <a name='s1-4.3'></a>
# ### Random Rotation ###
# Now let us perform additional data augmentation by as rotating each image (by a random angle). To generate a random angle, we can use `random.uniform`, and `rotate` for the rotation. We create another pipeline that uses the GPU to perform augmentations. DALI makes this transition very easy. The only thing that changes is the definition of the `rotate` operator. We only need to set the device argument to `gpu` and make sure that its input is transferred to the GPU by calling `.gpu()`.

# %%
# DO NOT CHANGE THIS CELL
@pipeline_def
def rotate_pipeline():
    images, _=fn.readers.file(file_root=image_dir)
    masks, _=fn.readers.file(file_root=mask_dir)
    images=fn.decoders.image(images, device='cpu')
    masks=fn.decoders.image(masks, device='cpu')
    
    angle=fn.random.uniform(range=(-30.0, 30.0))
    rotated_images = fn.rotate(images.gpu(), angle=angle, fill_value=0, keep_size=True, device='gpu')
    rotated_masks = fn.rotate(masks.gpu(), angle=angle, fill_value=0, keep_size=True, device='gpu')
    
    return rotated_images, rotated_masks

# %% [markdown]
# The `rotate_pipeline` now performs the rotations on the GPU. Keep in mind that the resulting images are also allocated in the GPU memory, which is typically what we want, since the model requires the data in GPU memory. In any case, copying back the data to CPU memory after running the pipeline can be easily achieved by calling `as_cpu` on the objects returned by `Pipeline.run()`.

# %%
# DO NOT CHANGE THIS CELL
pipe=rotate_pipeline(batch_size=batch_size, num_threads=4, device_id=0)
pipe.build()
rotate_pipe_output= pipe.run()

# %%
# DO NOT CHANGE THIS CELL
# define a function display images
def show_rotate_images(pipe_output):
    image_batch, rotated_batch=pipe_output
    columns=batch_size
    rows=2
    fig=plt.figure(figsize=(15, (15 // columns) * rows))
    gs=gridspec.GridSpec(rows, columns)
    grid_data=[image_batch.as_cpu(), rotated_batch.as_cpu()]
    grid=0
    for row_idx in range(rows): 
        for col_idx in range(columns): 
            plt.subplot(gs[grid])
            plt.axis('off')
            plt.imshow(grid_data[row_idx].at(col_idx))
            grid+=1
    plt.tight_layout()

# %%
# DO NOT CHANGE THIS CELL
show_rotate_images(rotate_pipe_output)

# %% [markdown]
# **Well Done!** Let's move to the [next notebook](./02_efficient_model_training.ipynb).

# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>
